# %% [markdown]
# # [Tarea 06] Unidad 03-A | Serie de Taylor y Polinomios de Lagrange

# %% [markdown]
# * Nombre:Freddy Jimenez
# * Curso:Gr1cc
# * Materia: Metodos Númericos
# * Fecha: 29/10/2024

# %% [markdown]
# ## CONJUNTO DE EJERCICIOS. -
#
# - Determine el orden de la mejor aproximación para las siguientes funciones, usando la Serie de Taylor y el Polinomio de Lagrange:
#
# - Funciones. -
#
# ![](imagen1.png)

# %% [markdown]
# ### SERIES DE TAYLOR. -

# %% [markdown]
# #### 1ra. FUNCION. -

# %%
import numpy as np
import matplotlib.pyplot as plt

def funcion_original(x):
    return 1 / (25 * x**2 + 1)

# Función 1
def f(x):
    return 625*x**4 - 25*x**2 + 1

# Generar valores de x
x = np.arange(-0.2, 0.2, 0.001)

# Calcular la función original y el polinomio de Taylor
y = f(x)
y_taylor = 1 + -25*x**2 + 625*x**4

# Crear la gráfica
plt.figure(figsize=(8, 6))
plt.plot(x, y_taylor, label='Polinomio de Taylor de orden n=5')
plt.plot(x, funcion_original(x), label='Función Original 1')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Aproximaciones de Taylor Freddy Jimenez')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### 2da. FUNCION. -

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

# Definir la función original y el punto de expansión
x = sp.Symbol('x')
f = sp.atan(x)
x0 = 1

# Calcular el polinomio de Taylor de orden 5
n = 5
taylor_series = sp.series(f, x, x0, n+1).removeO()

# Convertir la serie de Taylor a una función lambda para evaluar numéricamente
taylor_func = sp.lambdify(x, taylor_series, 'numpy')
original_func = sp.lambdify(x, f, 'numpy')

# Crear valores de x para graficar
x_vals = np.linspace(-2, 4, 500)
y_original = original_func(x_vals)
y_taylor = taylor_func(x_vals)

# Graficar la función original y la aproximación de Taylor
plt.figure(figsize=(10, 6))
plt.plot(x_vals, y_original, label="Función original", color="blue")
plt.plot(x_vals, y_taylor, label=f"Polinomio de Taylor de orden {n}", color="black", linestyle="--")
plt.axvline(x=x0, color="gray", linestyle=":", label=f"Punto de expansión ($x_0={x0}$)")
plt.title("Aproximaciones de Taylor Freddy Jimenez")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### POLINOMIO DE LAGRANGE. -

# %% [markdown]
# #### 1ra. FUNCION. -

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir la función original
def original_function(x):
    return 1 / (25 * x**2 + 1)

# Definir manualmente el polinomio de Lagrange
def lagrange_manual(x):
    return -5 * x**2 + 1

# Puntos originales
original_points_x = [0, -0.4, 0.4]
original_points_y = [1, 0.2, 0.2]

# Generar valores de x para graficar
x_vals = np.linspace(-0.4, 0.4, 500)
y_original = original_function(x_vals)
y_lagrange = lagrange_manual(x_vals)

# Graficar la función original, el polinomio y los puntos originales
plt.figure(figsize=(10, 6))
plt.plot(x_vals, y_original, label="Función original", color="black")
plt.plot(x_vals, y_lagrange, label="Polinomio de Lagrange manual (-5x^2 + 1)", color="blue", linestyle="--")
plt.scatter(original_points_x, original_points_y, color="red", label="Puntos originales", zorder=5)
plt.title("Interpolación de Lagrange (Manual)")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #### 2da. FUNCION. -

# %%
import numpy as np
import matplotlib.pyplot as plt

# Función original
def f(x):
    return np.arctan(x)

# Aproximación de Taylor de segundo orden
def taylor_approx(x):
    pi_4 = np.pi / 4
    return pi_4 + 0.5 * (x - 1) - 0.25 * (x - 1)**2

# Valores de x
x_values = np.linspace(0, 2, 400)
y_values_original = f(x_values)
y_values_approx = taylor_approx(x_values)

# Gráfica
plt.plot(x_values, y_values_original, label="arctan(x)", color="blue")
plt.plot(x_values, y_values_approx, label="Aproximación de Taylor", color="red", linestyle='--')
plt.scatter(1, f(1), color="green", zorder=5)  # Poner el punto en x0
plt.title("Aproximación de Taylor de segundo orden de arctan(x) en x0=1 Freddy Jimenez")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.show()
