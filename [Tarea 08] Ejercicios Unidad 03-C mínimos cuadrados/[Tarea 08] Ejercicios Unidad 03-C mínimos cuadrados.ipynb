# %% [markdown]
# # ESCUELA POLITECNICA NACIONAL
# - Nombre: Freddy Jimenez
# - Curso: Gr1cc
# - Fecha: 08/01/2024

# %% [markdown]
# ## Repositorio. -
#
# link : https://github.com/freddy1604/RepositorioDeMetodosNumericos/tree/main/%5BTarea%2008%5D%20Ejercicios%20Unidad%2003-C%20m%C3%ADnimos%20cuadrados

# %% [markdown]
# # [Tarea 08] Ejercicios Unidad 03-C mínimos cuadrados

# %% [markdown]
# Resuelva los ejercicios adjuntos.
#
# Indicaciones. -
# - En todos los ejercicios debe graficar los puntos dados y la/s línea/s ajustadas.
# - Subir el código con la resolución de los ejercicios en un repositorio público en Github.
# - Incluir enlace de su repositorio.
# - Subir archivo pdf.
# - Puede realizar los cálculos a mano, o utilizar cualquier librería o implementar su propia función.

# %% [markdown]
# ## CONJUNTO DE EJERCICIOS. -

# %% [markdown]
# ### 1. Dados los datos:
#
# ![](Imagen1.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Datos
xi = np.array([4.0, 4.2, 4.5, 4.7, 5.1, 5.5, 5.9, 6.3, 6.8, 7.1])
yi = np.array([102.56, 130.11, 113.18, 142.05, 167.53, 195.14, 224.87, 256.73, 299.50, 326.72])

# Error (diferencia cuadrática media)
def calcular_error(y_real, y_pred):
    return np.mean((y_real - y_pred) ** 2)

# a) Polinomio de grado 1
coef1 = np.polyfit(xi, yi, 1)
p1 = np.poly1d(coef1)
y1_pred = p1(xi)
error1 = calcular_error(yi, y1_pred)

# b) Polinomio de grado 2
coef2 = np.polyfit(xi, yi, 2)
p2 = np.poly1d(coef2)
y2_pred = p2(xi)
error2 = calcular_error(yi, y2_pred)

# c) Polinomio de grado 3
coef3 = np.polyfit(xi, yi, 3)
p3 = np.poly1d(coef3)
y3_pred = p3(xi)
error3 = calcular_error(yi, y3_pred)

# d) Modelo de la forma b * e^(a*x)
def modelo_exp(x, a, b):
    return b * np.exp(a * x)

param_exp, _ = curve_fit(modelo_exp, xi, yi)
y_exp_pred = modelo_exp(xi, *param_exp)
error_exp = calcular_error(yi, y_exp_pred)

# e) Modelo de la forma b * x^a
def modelo_pot(x, a, b):
    return b * x**a

param_pot, _ = curve_fit(modelo_pot, xi, yi)
y_pot_pred = modelo_pot(xi, *param_pot)
error_pot = calcular_error(yi, y_pot_pred)

# Resultados
print("a) Polinomio de grado 1:", coef1, "Error:", error1)
print("b) Polinomio de grado 2:", coef2, "Error:", error2)
print("c) Polinomio de grado 3:", coef3, "Error:", error3)
print("d) Modelo exponencial: a =", param_exp[0], ", b =", param_exp[1], "Error:", error_exp)
print("e) Modelo potencial: a =", param_pot[0], ", b =", param_pot[1], "Error:", error_pot)

# Gráficos
x_vals = np.linspace(min(xi), max(xi), 100)

# Polinomio de grado 1
plt.figure()
plt.scatter(xi, yi, color="red", label="Datos")
plt.plot(x_vals, np.poly1d(coef1)(x_vals), label="Grado 1", color="blue")
plt.legend()
plt.title("Ajuste: Polinomio de Grado 1")
plt.xlabel("xi")
plt.ylabel("yi")
plt.show()

# Polinomio de grado 2
plt.figure()
plt.scatter(xi, yi, color="red", label="Datos")
plt.plot(x_vals, np.poly1d(coef2)(x_vals), label="Grado 2", color="green")
plt.legend()
plt.title("Ajuste: Polinomio de Grado 2")
plt.xlabel("xi")
plt.ylabel("yi")
plt.show()

# Polinomio de grado 3
plt.figure()
plt.scatter(xi, yi, color="red", label="Datos")
plt.plot(x_vals, np.poly1d(coef3)(x_vals), label="Grado 3", color="purple")
plt.legend()
plt.title("Ajuste: Polinomio de Grado 3")
plt.xlabel("xi")
plt.ylabel("yi")
plt.show()

# Modelo exponencial
plt.figure()
plt.scatter(xi, yi, color="red", label="Datos")
plt.plot(x_vals, modelo_exp(x_vals, *param_exp), label="Exponencial", color="orange")
plt.legend()
plt.title("Ajuste: Modelo Exponencial")
plt.xlabel("xi")
plt.ylabel("yi")
plt.show()

# Modelo potencial
plt.figure()
plt.scatter(xi, yi, color="red", label="Datos")
plt.plot(x_vals, modelo_pot(x_vals, *param_pot), label="Potencial", color="brown")
plt.legend()
plt.title("Ajuste: Modelo Potencial")
plt.xlabel("xi")
plt.ylabel("yi")
plt.show()
# Out:
# a) Polinomio de grado 1: [  71.61024372 -191.57241853] Error: 105.88388862638904
# b) Polinomio de grado 2: [  8.21707232 -19.30860379  51.00078939] Error: 55.16562001170232
# c) Polinomio de grado 3: [  -2.60683872   51.56095694 -254.87478338  469.16326528] Error: 51.83830647403006
# d) Modelo exponencial: a = 0.3549271021279226 , b = 26.840771540960706 Error: 74.36215913505346
# e) Modelo potencial: a = 2.015190342585292 , b = 6.283966084740469 Error: 57.25817542056742

# %% [markdown]
# ### 2. Repita el ejercicio 5 para los siguientes datos.
#
# ![](imagen2.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Datos
xi = np.array([0.2, 0.3, 0.6, 0.9, 1.1, 1.3, 1.4, 1.6])
yi = np.array([0.050446, 0.098426, 0.33277, 0.72660, 1.0972, 1.5697, 1.8487, 2.5015])

# Error (diferencia cuadrática media)
def calcular_error(y_real, y_pred):
    return np.mean((y_real - y_pred) ** 2)

# a) Polinomio de grado 1
coef1 = np.polyfit(xi, yi, 1)
p1 = np.poly1d(coef1)
y1_pred = p1(xi)
error1 = calcular_error(yi, y1_pred)

# b) Polinomio de grado 2
coef2 = np.polyfit(xi, yi, 2)
p2 = np.poly1d(coef2)
y2_pred = p2(xi)
error2 = calcular_error(yi, y2_pred)

# c) Polinomio de grado 3
coef3 = np.polyfit(xi, yi, 3)
p3 = np.poly1d(coef3)
y3_pred = p3(xi)
error3 = calcular_error(yi, y3_pred)

# d) Modelo de la forma b * e^(a*x)
def modelo_exp(x, a, b):
    return b * np.exp(a * x)

param_exp, _ = curve_fit(modelo_exp, xi, yi)
y_exp_pred = modelo_exp(xi, *param_exp)
error_exp = calcular_error(yi, y_exp_pred)

# e) Modelo de la forma b * x^a
def modelo_pot(x, a, b):
    return b * x**a

param_pot, _ = curve_fit(modelo_pot, xi, yi)
y_pot_pred = modelo_pot(xi, *param_pot)
error_pot = calcular_error(yi, y_pot_pred)

# Resultados
print("a) Polinomio de grado 1:", coef1, "Error:", error1)
print("b) Polinomio de grado 2:", coef2, "Error:", error2)
print("c) Polinomio de grado 3:", coef3, "Error:", error3)
print("d) Modelo exponencial: a =", param_exp[0], ", b =", param_exp[1], "Error:", error_exp)
print("e) Modelo potencial: a =", param_pot[0], ", b =", param_pot[1], "Error:", error_pot)

# Gráficos
x_vals = np.linspace(min(xi), max(xi), 100)

# Polinomio de grado 1
plt.figure()
plt.scatter(xi, yi, color="red", label="Datos")
plt.plot(x_vals, np.poly1d(coef1)(x_vals), label="Grado 1", color="blue")
plt.legend()
plt.title("Ajuste: Polinomio de Grado 1")
plt.xlabel("xi")
plt.ylabel("yi")
plt.show()

# Polinomio de grado 2
plt.figure()
plt.scatter(xi, yi, color="red", label="Datos")
plt.plot(x_vals, np.poly1d(coef2)(x_vals), label="Grado 2", color="green")
plt.legend()
plt.title("Ajuste: Polinomio de Grado 2")
plt.xlabel("xi")
plt.ylabel("yi")
plt.show()

# Polinomio de grado 3
plt.figure()
plt.scatter(xi, yi, color="red", label="Datos")
plt.plot(x_vals, np.poly1d(coef3)(x_vals), label="Grado 3", color="purple")
plt.legend()
plt.title("Ajuste: Polinomio de Grado 3")
plt.xlabel("xi")
plt.ylabel("yi")
plt.show()

# Modelo exponencial
plt.figure()
plt.scatter(xi, yi, color="red", label="Datos")
plt.plot(x_vals, modelo_exp(x_vals, *param_exp), label="Exponencial", color="orange")
plt.legend()
plt.title("Ajuste: Modelo Exponencial")
plt.xlabel("xi")
plt.ylabel("yi")
plt.show()

# Modelo potencial
plt.figure()
plt.scatter(xi, yi, color="red", label="Datos")
plt.plot(x_vals, modelo_pot(x_vals, *param_pot), label="Potencial", color="brown")
plt.legend()
plt.title("Ajuste: Modelo Potencial")
plt.xlabel("xi")
plt.ylabel("yi")
plt.show()
# Out:
# a) Polinomio de grado 1: [ 1.66554008 -0.51245682] Error: 0.041948731969935996
# b) Polinomio de grado 2: [ 1.12942387 -0.31140346  0.08514393] Error: 0.0003024893661783383
# c) Polinomio de grado 3: [ 0.2662081   0.40293221  0.24838578 -0.0184014 ] Error: 6.343339444533196e-07
# d) Modelo exponencial: a = 1.8583147677366632 , b = 0.1325863281274722 Error: 0.008498467250191457
# e) Modelo potencial: a = 2.1427728837706423 , b = 0.9055224503277092 Error: 0.00043594151427458333

# %% [markdown]
# ### 3.
#
# La siguiente tabla muestra los promedios de puntos del colegio de 20 especialistas en matemáticas y ciencias computacionales, junto con las calificaciones
#
# que recibieron estos estudiantes en la parte de matemáticas de la prueba ACT (Programa de Pruebas de Colegios Americanos) mientras estaban en secundaria.
#
# Grafique estos datos y encuentre la ecuación de la recta por mínimos cuadrados para estos datos.
#
# ![](imagen3.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos
puntuacion_ACT = np.array([28, 25, 28, 27, 28, 33, 28, 29, 23, 27, 29, 28, 28, 27, 29, 21, 28, 26, 30, 24])
promedio_puntos = np.array([3.84, 3.21, 3.23, 3.63, 3.75, 3.20, 3.41, 3.38, 3.53, 2.03, 
                            3.75, 3.65, 3.87, 3.75, 3.12, 1.66, 2.96, 2.92, 3.10, 2.81])

# Cálculo de la recta de mínimos cuadrados
coef = np.polyfit(puntuacion_ACT, promedio_puntos, 1)  # Ajuste lineal (grado 1)
recta = np.poly1d(coef)

# Ecuación de la recta
print(f"Ecuación de la recta: y = {coef[0]:.4f}x + {coef[1]:.4f}")

# Gráfico
x_vals = np.linspace(min(puntuacion_ACT), max(puntuacion_ACT), 100)
y_vals = recta(x_vals)

plt.figure()
plt.scatter(puntuacion_ACT, promedio_puntos, color="red", label="Datos")
plt.plot(x_vals, y_vals, color="blue", label=f"Recta: y = {coef[0]:.4f}x + {coef[1]:.4f}")
plt.title("Regresión lineal: Puntuación ACT vs Promedio de puntos")
plt.xlabel("Puntuación ACT")
plt.ylabel("Promedio de puntos")
plt.legend()
plt.grid()
plt.show()
# Out:
# Ecuación de la recta: y = 0.0969x + 0.5952

# %% [markdown]
# ### 4.
#
# El siguiente conjunto de datos, presentado al Subcomité Antimonopolio del Senado, muestra las características comparativas de supervivencia durante un
#
# choque de automóviles de diferentes clases. Encuentre la recta por mínimos cuadrados que aproxima estos datos (la tabla muestra el porcentaje de vehículos
#
# que participaron en un accidente en los que la lesión más grave fue fatal o seria)
#
# ![](imagen4.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de la tabla
peso_promedio = np.array([4800, 3700, 3400, 2800, 1900])  # en libras
porcentaje_presentacion = np.array([3.1, 4.0, 5.2, 6.4, 9.6])  # en porcentaje

# Cálculo de la recta de mínimos cuadrados
n = len(peso_promedio)
x_mean = np.mean(peso_promedio)
y_mean = np.mean(porcentaje_presentacion)

# Pendiente (m) y ordenada al origen (b)
m = np.sum((peso_promedio - x_mean) * (porcentaje_presentacion - y_mean)) / np.sum((peso_promedio - x_mean)**2)
b = y_mean - m * x_mean

# Ecuación de la recta
print(f"Ecuación de la recta: y = {m:.4f}x + {b:.4f}")

# Graficar los datos y la recta
plt.scatter(peso_promedio, porcentaje_presentacion, color='blue', label='Datos')
plt.plot(peso_promedio, m * peso_promedio + b, color='red', label='Recta de mínimos cuadrados')
plt.xlabel('Peso promedio (lb)')
plt.ylabel('Porcentaje de presentación (%)')
plt.title('Aproximación por mínimos cuadrados')
plt.legend()
plt.grid()
plt.show()
# Out:
# Ecuación de la recta: y = -0.0023x + 13.1465
