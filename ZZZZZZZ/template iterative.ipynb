# %%
# %load_ext autoreload

# %% [markdown]
# # **ESCUELA POLITECNICA NACIONAL**
# - Nombre: Freddy Jimenez
# - Curso: Gr1cc
# - Fecha: 25/01/2025

# %% [markdown]
# ## **REPOSITORIO. -**
# - Link:

# %% [markdown]
# ## **ACTIVIDAD EN CLASE. -**

# %% [markdown]
# ### **INDICACIONES. -**
# **RESOLVER SISTEMA**
# - Usando funciones provistas
# - Gauss Jacobi, Gauss Seidel

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
import numpy as np

# Definición del sistema de ecuaciones
# 2x + 10y = 16
# 3x + 2y = 11
A = np.array([[2, 10], [3, 2]], dtype=float)
b = np.array([[16], [11]], dtype=float)

# Parámetros iniciales
x0 = np.array([[1], [1]], dtype=float)  # Vector inicial [1, 1]
tol = 1e-6  # Tolerancia
max_iter = 100  # Número máximo de iteraciones

# Resolver usando Gauss-Jacobi
x_jacobi, tray_jacobi = gauss_jacobi(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)

# Resolver usando Gauss-Seidel
x_seidel, tray_seidel = gauss_seidel(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)

# Mostrar resultados hasta la iteración 13
print("Método de Gauss-Jacobi:")
print(f"Solución: \n{x_jacobi}")
print("Trayectoria de aproximaciones hasta la iteración 13:")
for step, approx in enumerate(tray_jacobi[:13]):
    print(f"Iteración {step + 1}: {approx.T}")

print("\nMétodo de Gauss-Seidel:")
print(f"Solución: \n{x_seidel}")
print("Trayectoria de aproximaciones hasta la iteración 13:")
for step, approx in enumerate(tray_seidel[:13]):
    print(f"Iteración {step + 1}: {approx.T}")
# Out:
# [01-25 08:26:17][INFO] i= 0 x: [[1. 1.]]
# [01-25 08:26:17][INFO] i= 1 x: [[3. 4.]]
# [01-25 08:26:17][INFO] i= 2 x: [[-12.   1.]]
# [01-25 08:26:17][INFO] i= 3 x: [[ 3.  23.5]]
# [01-25 08:26:17][INFO] i= 4 x: [[-109.5    1. ]]
# [01-25 08:26:17][INFO] i= 5 x: [[  3.   169.75]]
# [01-25 08:26:17][INFO] i= 6 x: [[-840.75    1.  ]]
# [01-25 08:26:17][INFO] i= 7 x: [[   3.    1266.625]]
# [01-25 08:26:17][INFO] i= 8 x: [[-6.325125e+03  1.000000e+00]]
# [01-25 08:26:17][INFO] i= 9 x: [[3.0000000e+00 9.4931875e+03]]
# [01-25 08:26:17][INFO] i= 10 x: [[-4.74579375e+04  1.00000000e+00]]
# [01-25 08:26:17][INFO] i= 11 x: [[3.00000000e+00 7.11924062e+04]]
# [01-25 08:26:17][INFO] i= 12 x: [[-3.55954031e+05  1.00000000e+00]]
# [01-25 08:26:17][INFO] i= 13 x: [[3.00000000e+00 5.33936547e+05]]
# [01-25 08:26:17][INFO] i= 14 x: [[-2.66967473e+06  1.00000000e+00]]
# [01-25 08:26:17][INFO] i= 15 x: [[3.0000000e+00 4.0045176e+06]]
# [01-25 08:26:17][INFO] i= 16 x: [[-2.002258e+07  1.000000e+00]]
# ...

# %% [markdown]
# ### **GRAFICAR TRAYECTORIA DIVERGENCIA. -**
# - Obtener trayectoria de puntos
# - Desde $x_0$ hasta sol

# %% [markdown]
# ### **GRAFICAR TRAYECTORIA CONVERGENCIA. -**
# - Intercambiar filas
