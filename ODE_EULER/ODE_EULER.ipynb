# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # ESCUELA POLITECNICA NACIONAL
# - Nombre: Freddy Jimenez
# - Curso: Gr1cc
# - Fecha: 05/02/2025

# %% [markdown]
# ## REPOSITORIO. -
#
# Link: https://github.com/freddy1604/RepositorioDeMetodosNumericos/tree/main/ODE_EULER

# %% [markdown]
# ## ACTIVIDAD EN CLASE DE EDO_EULER

# %% [markdown]
# ### EJERCICIO 1.-
# - DIBUJAR $Y_{real}$ y $Y_{aprox}$

# %%
from src import ODE_euler

a = 0
b = 2
f = lambda t, y: y - t**2 + 1

y_t0 = 0.5
N = 10

y_values, t_values, h = ODE_euler(a=a, b=b, f=f, y_t0=y_t0, N=N)

# %%
import matplotlib.pyplot as plt
import numpy as np

def y_real(t):
    return (t + 1)**2 - 0.5 * np.exp(t)

t_continuous = np.linspace(a, b, 100)
y_continuous = y_real(t_continuous)

# Graficade aproximacion y real
plt.plot(t_values, y_values, 'o-.', label='solucion con el metodo de Euler')
plt.plot(t_continuous, y_continuous, label='solucion real')

plt.xlabel('t')
plt.ylabel('y')
plt.title('Metodo de Euler')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### EJERCICIO 2. -
# - Dibujar en 2do grafico 3 Valores de 'N'
# - N = 20
# - N = 10
# - N = 5

# %%
from src import ODE_euler
import numpy as np

import matplotlib.pyplot as plt

def f(t, y):
    return y - t**2 + 1

a = 0
y0 = 0.5
b = 2
N = 10

y_values, t_values, h = ODE_euler(a=a, b=b, f=f, y_t0=y0, N=N)

print("t_values\t y_values")
print("------------------------")
for t, y in zip(t_values, y_values):
    print(f"{t:.4f}\t {y:.4f}")

def exact_solution(t):
    return (t + 1)**2 - 0.5 * np.exp(t)

t_exact = np.linspace(a, b, 100)
y_exact = exact_solution(t_exact)
# Out:
# t_values	 y_values
# ------------------------
# 0.0000	 0.5000
# 0.2000	 0.8000
# 0.4000	 1.1520
# 0.6000	 1.5504
# 0.8000	 1.9885
# 1.0000	 2.4582
# 1.2000	 2.9498
# 1.4000	 3.4518
# 1.6000	 3.9501
# 1.8000	 4.4282
# 2.0000	 4.8658

# %%
y_values2, t_values2, h = ODE_euler(a=a, b=b, f=f, y_t0=y0, N=5)

print("t_values\t y_values")
print("------------------------")
for t, y in zip(t_values2, y_values2):
    print(f"{t:.4f}\t {y:.4f}")
# Out:
# t_values	 y_values
# ------------------------
# 0.0000	 0.5000
# 0.4000	 1.1000
# 0.8000	 1.8760
# 1.2000	 2.7704
# 1.6000	 3.7026
# 2.0000	 4.5596

# %%
y_values20, t_values20, h = ODE_euler(a=a, b=b, f=f, y_t0=y0, N=20)

print("t_values\t y_values")
print("------------------------")
for t, y in zip(t_values20, y_values20):
    print(f"{t:.4f}\t {y:.4f}")
# Out:
# t_values	 y_values
# ------------------------
# 0.0000	 0.5000
# 0.1000	 0.6500
# 0.2000	 0.8140
# 0.3000	 0.9914
# 0.4000	 1.1815
# 0.5000	 1.3837
# 0.6000	 1.5971
# 0.7000	 1.8208
# 0.8000	 2.0538
# 0.9000	 2.2952
# 1.0000	 2.5438
# 1.1000	 2.7981
# 1.2000	 3.0569
# 1.3000	 3.3186
# 1.4000	 3.5815
# 1.5000	 3.8437
# 1.6000	 4.1030
# 1.7000	 4.3573
# 1.8000	 4.6040
# 1.9000	 4.8405
# 2.0000	 5.0635

# %%
plt.plot(t_values, y_values, label='Euler con N=10', marker='o')
plt.plot(t_values2, y_values2, label='Euler con N=5', marker='o')
plt.plot(t_values20, y_values20, label='Euler con N=20', marker='o')
plt.plot(t_exact, y_exact, label=' Solucion Exacta', linestyle='--')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Solución ODE usando el método de Euler')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### EJERCICIO 3. -
# - Repetir el 2do Ejercicio

# %%
from src import ODE_euler
import numpy as np

import matplotlib.pyplot as plt

def f(t, y):
    return y/t - (y/t)**2

a = 1
y0 = 1
b = 2
N = 10

y_values, t_values, h = ODE_euler(a=a, b=b, f=f, y_t0=y0, N=N)

print("t_values\t y_values")
print("------------------------")
for t, y in zip(t_values, y_values):
    print(f"{t:.4f}\t {y:.4f}")

def exact_solution(t):
    return t/(1 + np.log(t))

t_exact = np.linspace(a, b, 100)
y_exact = exact_solution(t_exact)
# Out:
# t_values	 y_values
# ------------------------
# 1.0000	 1.0000
# 1.1000	 1.0000
# 1.2000	 1.0083
# 1.3000	 1.0217
# 1.4000	 1.0385
# 1.5000	 1.0577
# 1.6000	 1.0785
# 1.7000	 1.1004
# 1.8000	 1.1233
# 1.9000	 1.1467
# 2.0000	 1.1707

# %%
y_values2, t_values2, h = ODE_euler(a=a, b=b, f=f, y_t0=y0, N=5)

print("t_values\t y_values")
print("------------------------")
for t, y in zip(t_values2, y_values2):
    print(f"{t:.4f}\t {y:.4f}")
# Out:
# t_values	 y_values
# ------------------------
# 1.0000	 1.0000
# 1.2000	 1.0000
# 1.4000	 1.0278
# 1.6000	 1.0668
# 1.8000	 1.1113
# 2.0000	 1.1585

# %%
y_values20, t_values20, h = ODE_euler(a=a, b=b, f=f, y_t0=y0, N=20)

print("t_values\t y_values")
print("------------------------")
for t, y in zip(t_values20, y_values20):
    print(f"{t:.4f}\t {y:.4f}")
# Out:
# t_values	 y_values
# ------------------------
# 1.0000	 1.0000
# 1.0500	 1.0000
# 1.1000	 1.0023
# 1.1500	 1.0063
# 1.2000	 1.0118
# 1.2500	 1.0184
# 1.3000	 1.0259
# 1.3500	 1.0343
# 1.4000	 1.0432
# 1.4500	 1.0527
# 1.5000	 1.0627
# 1.5500	 1.0730
# 1.6000	 1.0836
# 1.6500	 1.0946
# 1.7000	 1.1057
# 1.7500	 1.1171
# 1.8000	 1.1286
# 1.8500	 1.1403
# 1.9000	 1.1522
# 1.9500	 1.1641
# 2.0000	 1.1761

# %%
y_values15, t_values15, h = ODE_euler(a=a, b=b, f=f, y_t0=y0, N=15)

print("t_values\t y_values")
print("------------------------")
for t, y in zip(t_values15, y_values15):
    print(f"{t:.4f}\t {y:.4f}")
# Out:
# t_values	 y_values
# ------------------------
# 1.0000	 1.0000
# 1.0667	 1.0000
# 1.1333	 1.0039
# 1.2000	 1.0107
# 1.2667	 1.0195
# 1.3333	 1.0300
# 1.4000	 1.0417
# 1.4667	 1.0544
# 1.5333	 1.0679
# 1.6000	 1.0820
# 1.6667	 1.0966
# 1.7333	 1.1116
# 1.8000	 1.1269
# 1.8667	 1.1425
# 1.9333	 1.1583
# 2.0000	 1.1743

# %%
plt.plot(t_values, y_values, label='Euler con N=10', marker='o')
plt.plot(t_values2, y_values2, label='Euler con N=5', marker='o')
plt.plot(t_values20, y_values20, label='Euler con N=20', marker='o')
plt.plot(t_exact, y_exact, label=' Solucion Exacta', linestyle='--')
plt.xlabel('t')
plt.ylabel('y')
plt.title('Solución ODE usando el método de Euler')
plt.legend()
plt.grid()
plt.show()
